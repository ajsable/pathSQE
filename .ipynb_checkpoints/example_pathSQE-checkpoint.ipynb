# %% [markdown]
# # setup

# %%
import imp
import sys
from pathSQE_functions import *
sys.path.append('files_for_nb')
from reduce_data_to_MDE_07142023 import *
from slice_utils_07142023 import *
import define_data
# Out:
# FrameworkManager-[Notice] Welcome to Mantid 6.7.0
# FrameworkManager-[Notice] Please cite: http://dx.doi.org/10.1016/j.nima.2014.07.029 and this release: http://dx.doi.org/10.5286/Software/Mantid6.7

# %% [markdown]
# # Example data

# %% [markdown]
# FeSi unit cell:
#
# <img src="files_for_nb/FeSi_unitCell.png" alt="Alternative text" />

# %% [markdown]
# FeSi BZ and high symmetry path:
#
# <img src="files_for_nb/FeSi_highSymPath1_sm.png" alt="Alternative text" />

# %% [markdown]
# # Plot along path for many BZ

# %% [markdown]
# Whole process in 1 cell for 1st BZ

# %%
dsl_000 = make_all_slice_descs(path_to_poscar='files_for_nb/POSCAR', BZ_offset=np.array([0,0,0]))

imp.reload(define_data)

mde_data=define_data.define_data_set()
reduce_data_to_MDE(mde_data)

for i in range(len(dsl_000)):
    make_slice(mde_data[0],dsl_000[i], ASCII_slice_folder='', MD_slice_folder='')
# Out:
# Try loading MDE from /SNS/ARCS/IPTS-21211/shared/Aiden/merged_mde/FeSi_650K_70meV_UBcorrected.nxs
# LoadMD-[Notice] LoadMD started
# Loading normalization and masking file /SNS/ARCS/IPTS-21211/shared/Dipanshu/van108467_new.nxs
# LoadMD-[Notice] LoadMD successful, Duration 3 minutes 41.89 seconds
# Load-[Notice] Load started
# Load-[Notice] Load successful, Duration 3.76 seconds
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 16.41 seconds
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 16.05 seconds
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 17.16 seconds
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 17.80 seconds
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 17.48 seconds

# %%
fig2v = plot_along_path(dsl_000,3e-5,2e-3,'viridis')
fig2v.show()

# %% [markdown]
# # For plotting non-1st BZ

# %% [markdown]
# 006

# %%
dsl_006 = make_all_slice_descs(path_to_poscar='files_for_nb/POSCAR', BZ_offset=np.array([0,0,6]))

imp.reload(define_data)

mde_data=define_data.define_data_set()
reduce_data_to_MDE(mde_data)

for i in range(len(dsl_006)):
    make_slice(mde_data[0],dsl_006[i], ASCII_slice_folder='', MD_slice_folder='')
# Out:
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 16.81 seconds
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 16.74 seconds
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 15.92 seconds
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 16.83 seconds
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 16.68 seconds

# %%
fig3v = plot_along_path(dsl_006,3e-5,2e-3,'viridis')
fig3v.show()
fig3 = plot_along_path(dsl_006,6e-5,2e-3)
fig3.show()

# %% [markdown]
# ## -4 -4 0

# %%
dsl_m4m40 = make_all_slice_descs(path_to_poscar='files_for_nb/POSCAR', BZ_offset=np.array([-4,-4,0]))

imp.reload(define_data)

mde_data=define_data.define_data_set()
reduce_data_to_MDE(mde_data)

for i in range(len(dsl_m4m40)):
    make_slice(mde_data[0],dsl_m4m40[i], ASCII_slice_folder='', MD_slice_folder='')
# Out:
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 16.25 seconds
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 16.12 seconds
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 16.55 seconds
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 16.61 seconds
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 16.42 seconds

# %%
fig4v = plot_along_path(dsl_m4m40,3e-5,1e-3,'viridis')
fig4v.show()
fig4 = plot_along_path(dsl_m4m40,6e-5,2e-3)
fig4.show()

# %% [markdown]
# -3 -3 -5

# %%
dsl_m3m3m5 = make_all_slice_descs(path_to_poscar='files_for_nb/POSCAR', BZ_offset=np.array([-3,-3,-5]))

imp.reload(define_data)

mde_data=define_data.define_data_set()
reduce_data_to_MDE(mde_data)

for i in range(len(dsl_m3m3m5)):
    make_slice(mde_data[0],dsl_m3m3m5[i], ASCII_slice_folder='', MD_slice_folder='')
# Out:
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 16.08 seconds
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 16.09 seconds
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 16.02 seconds
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 16.90 seconds
# MDNorm-[Notice] MDNorm started
# MDNorm-[Notice] MDNorm successful, Duration 16.02 seconds

# %%
fig5v = plot_along_path(dsl_m3m3m5,3e-5,8e-4,'viridis')
fig5v.show()
fig5 = plot_along_path(dsl_m3m3m5,4e-5,9e-4)
fig5.show()
